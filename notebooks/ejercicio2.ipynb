# %%
playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %%
new_playlist = []

max_index = 0
min_index  = 0
total_seconds = 0

for song in playlist:
  duration = song["duration"].split(":")
  minutes = int(duration[0])
  seconds = int(duration[1])
  total_seconds_song = (minutes * 60) + seconds
  new_playlist.append(total_seconds_song)
  total_seconds += total_seconds_song


final_minutes = total_seconds // 60
final_seconds = total_seconds  % 60

max_index = new_playlist.index(max(new_playlist))
min_index = new_playlist.index(min(new_playlist))


print(f'Duración total: {final_minutes}m {final_seconds}s')
print(f'Canción más larga: "{playlist[max_index].get("title")}" ({playlist[max_index].get("duration")})')
print(f'Canción más corta: "{playlist[min_index].get("title")}" ({playlist[min_index].get("duration")})')
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)
